# %%
import numpy as np
import gzip
from astropy.io import fits

# %%
path = '/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b.1p.1/run1/magx_t0300.fits.gz'

# %%
with fits.open(path) as hdul:
    hdul.info()
# Out:
# Filename: /mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b.1p.1/run1/magx_t0300.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      10   (256, 256, 256)   float32

# %%
with fits.open(path) as hdul:
    a = hdul['PRIMARY'].data
    print(a.shape)
# Out:
# (256, 256, 256)

# %%
t = np.linspace(300, 399, 100, dtype=int)
n_run = np.linspace(1, 10, 10, dtype=int)
bp = ['.1', '1']
pp = ['.01'] #, '.1', '.2', '1', '2']

# %%
n =10
t = np.linspace(0, 99, 100, dtype=int)
t +(300+(n-1)*100)
# Out:
# array([1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210,
#        1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221,
#        1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232,
#        1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243,
#        1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254,
#        1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265,
#        1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276,
#        1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287,
#        1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298,
#        1299])

# %%
int((300+(n-1)*100))
# Out:
# 1200

# %%
from tqdm import tqdm
import h5py
for b in bp:
    for p in pp:
        with h5py.File(f'/mnt/home/polymathic/ceph/the_well/3D/MHD/data/b{b}_p{p}.hdf5', 'w') as file:
            file.create_dataset('density', shape=(10, 100, 256, 256, 256), dtype='float32')
            file.create_dataset('mag_x', shape=(10, 100, 256, 256, 256), dtype='float32')
            file.create_dataset('mag_y', shape=(10, 100, 256, 256, 256), dtype='float32')
            file.create_dataset('mag_z', shape=(10, 100, 256, 256, 256), dtype='float32')
            file.create_dataset('velocity_x', shape=(10, 100, 256, 256, 256), dtype='float32')
            file.create_dataset('velocity_y', shape=(10, 100, 256, 256, 256), dtype='float32')
            file.create_dataset('velocity_z', shape=(10, 100, 256, 256, 256), dtype='float32')
            for n in n_run:
                for i, time in enumerate(t):
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/dens_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['density'][n-1, i] = hdul['PRIMARY'].data
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/magx_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['mag_x'][n-1, i] = hdul['PRIMARY'].data
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/magy_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['mag_y'][n-1, i] = hdul['PRIMARY'].data
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/magz_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['mag_z'][n-1, i] = hdul['PRIMARY'].data
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/velx_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['velocity_x'][n-1, i] = hdul['PRIMARY'].data
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/vely_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['velocity_y'][n-1, i] = hdul['PRIMARY'].data
                    path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/velz_t0{time}.fits.gz'
                    with fits.open(path) as hdul:
                        file['velocity_z'][n-1, i] = hdul['PRIMARY'].data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [51], line 16
#      14 for i, time in enumerate(t):
#      15     path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/dens_t0{time}.fits.gz'
# ---> 16     with fits.open(path) as hdul:
#      17         file['density'][n-1, i] = hdul['PRIMARY'].data
#      18     path = f'/mnt/home/polymathic/ceph/the_well/testing_before_adding/MHD/data/b{b}p{p}/run{n}/magx_t0{time}.fits.gz'
#
# File /mnt/sw/nix/store/b4q5asj8flwlgmaijgj1r6wbmnls5x8k-python-3.9.15-view/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:175, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     172 if not name:
#     173     raise ValueError(f'Empty filename: {name!r}')
# --> 175 return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# ...

# %%
with gzip.open(path, 'rb') as f:
    file_content = f.read()

# %%
array = np.frombuffer(file_content, dtype=np.float32)

# %%
file_content .shape
# Out:
# (16778160,)

# %%
16778160/256
# Out:
# 65539.6875
